# %%
run fileIO.py
# Out:
# Participants in 10001: 44

# %%
columns = df.columns
df[columns[0:5]].head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
#
#    COUNT MALE
# 0          22
# 1          16
# 2           0
# 3           0
# 4           0

# %%
df[columns[5:10]].head()
# Out:
#    PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          0.50                     0                       0
# 1          0.46                     0                       0
# 2          0.00                     0                       0
# 3          0.00                     0                       0
# 4          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL
# 0                  44                   100
# 1                  35                   100
# 2                   1                   100
# 3                   0                     0
# 4                   2                   100

# %%
df[columns[10:15]].head()
# Out:
#    COUNT PACIFIC ISLANDER  PERCENT PACIFIC ISLANDER  COUNT HISPANIC LATINO  \
# 0                       0                       0.0                     16
# 1                       0                       0.0                      1
# 2                       0                       0.0                      0
# 3                       0                       0.0                      0
# 4                       0                       0.0                      0
#
#    PERCENT HISPANIC LATINO  COUNT AMERICAN INDIAN
# 0                     0.36                      0
# 1                     0.03                      0
# 2                     0.00                      0
# 3                     0.00                      0
# 4                     0.00                      0

# %%
df[columns[15:20]].head()
# Out:
#    PERCENT AMERICAN INDIAN  COUNT ASIAN NON HISPANIC  \
# 0                      0.0                         3
# 1                      0.0                        28
# 2                      0.0                         1
# 3                      0.0                         0
# 4                      0.0                         1
#
#    PERCENT ASIAN NON HISPANIC  COUNT WHITE NON HISPANIC  \
# 0                        0.07                         1
# 1                        0.80                         6
# 2                        1.00                         0
# 3                        0.00                         0
# 4                        0.50                         0
#
#    PERCENT WHITE NON HISPANIC
# 0                        0.02
# 1                        0.17
# 2                        0.00
# 3                        0.00
# 4                        0.00

# %%
df[columns[20:25]].head()
# Out:
#    COUNT BLACK NON HISPANIC  PERCENT BLACK NON HISPANIC  \
# 0                        21                        0.48
# 1                         0                        0.00
# 2                         0                        0.00
# 3                         0                        0.00
# 4                         1                        0.50
#
#    COUNT OTHER ETHNICITY  PERCENT OTHER ETHNICITY  COUNT ETHNICITY UNKNOWN
# 0                      3                     0.07                        0
# 1                      0                     0.00                        0
# 2                      0                     0.00                        0
# 3                      0                     0.00                        0
# 4                      0                     0.00                        0

# %%
df[columns[25:30]].head()
# Out:
#    PERCENT ETHNICITY UNKNOWN  COUNT ETHNICITY TOTAL  PERCENT ETHNICITY TOTAL  \
# 0                        0.0                     44                      100
# 1                        0.0                     35                      100
# 2                        0.0                      1                      100
# 3                        0.0                      0                        0
# 4                        0.0                      2                      100
#
#    COUNT PERMANENT RESIDENT ALIEN  PERCENT PERMANENT RESIDENT ALIEN
# 0                               2                              0.05
# 1                               2                              0.06
# 2                               0                              0.00
# 3                               0                              0.00
# 4                               1                              0.50

# %%
df[columns[25:30]].head()
# Out:
#    PERCENT ETHNICITY UNKNOWN  COUNT ETHNICITY TOTAL  PERCENT ETHNICITY TOTAL  \
# 0                        0.0                     44                      100
# 1                        0.0                     35                      100
# 2                        0.0                      1                      100
# 3                        0.0                      0                        0
# 4                        0.0                      2                      100
#
#    COUNT PERMANENT RESIDENT ALIEN  PERCENT PERMANENT RESIDENT ALIEN
# 0                               2                              0.05
# 1                               2                              0.06
# 2                               0                              0.00
# 3                               0                              0.00
# 4                               1                              0.50

# %% [markdown]
# <br><br><br><br><br>

# %% [markdown]
# ## Dump Pandas to `list`
# * this is generally not what you want to do

# %%
demographic_data = df.values.tolist()

# %%
demographic_data[0]
# Out:
# [10001.0,
#  44.0,
#  22.0,
#  0.5,
#  22.0,
#  0.5,
#  0.0,
#  0.0,
#  44.0,
#  100.0,
#  0.0,
#  0.0,
#  16.0,
#  0.36,
#  0.0,
#  0.0,
#  3.0,
#  0.07,
#  1.0,
#  0.02,
#  21.0,
#  0.48,
#  3.0,
#  0.07,
#  0.0,
#  0.0,
#  44.0,
#  100.0,
#  2.0,
#  0.05,
#  42.0,
#  0.95,
#  0.0,
#  0.0,
#  0.0,
#  0.0,
#  44.0,
#  100.0,
#  20.0,
#  0.45,
#  24.0,
#  0.55,
#  0.0,
#  0.0,
#  44.0,
#  100.0]

# %%
df_dtypes = df.dtypes

# %%
type(df_dtypes)
str(df_dtypes[0])
# Out:
# 'int64'

# %%
for i, typ in enumerate(df_dtypes):
    if str(typ) == 'int64'
    ### convert each col in the 2nd dimension of our data list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-34fc7a11cb38> in <module>
# ----> 1 t
#
# NameError: name 't' is not defined
